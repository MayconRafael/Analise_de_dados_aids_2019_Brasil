# %%
import matplotlib
import pandas as pd 
import matplotlib.pyplot as plt
import numpy as np

# %%
low_memory=False,
# %matplotlib inline
pd.options.display.max_columns = 80
pd.options.display.max_rows = 90

# %%
df = pd.read_excel(r'C:\Users\User\Dados-AIDS-Genero-Escolaridade.xlsx')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Escolaridade      10 non-null     object
#  1   Masculino         10 non-null     int64
#  2   Feminino          10 non-null     int64
#  3   Total             10 non-null     int64
#  4   Regiao Residente  6 non-null      object
#  5   Masculino.1       6 non-null      float64
#  6   Feminino.1        6 non-null      float64
#  7   Total.1           6 non-null      float64
#  8   Raça/cor          6 non-null      object
#  9   Masculino.2       6 non-null      float64
#  10  Feminino.2        6 non-null      float64
#  11  Total.2           6 non-null      float64
# dtypes: float64(6), int64(3), object(3)
# memory usage: 1.1+ KB

# %%
x = np.arange(len(df.Escolaridade))
width = 0.20
fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, (df.Masculino), width, label='Masculino')
rects2 = ax.bar(x + width/2, (df.Feminino), width, label='Feminino')

ax.set_ylabel('Casos')
ax.set_title('Casos de AIDS correlacionados ao Ensino')
ax.set_xticks(x)
ax.set_xticklabels(df.Escolaridade)
ax.legend()

plt.show()
plt.rcParams["figure.figsize"] = [20, 5]

# %%
df = df.dropna()

x = np.arange(len(df["Regiao Residente"]))
width = 0.20
fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, (df["Masculino.1"]), width, label='Masculino')
rects2 = ax.bar(x + width/2, (df["Feminino.1"]), width, label='Masculino')

ax.set_ylabel('Casos')
ax.set_title('Casos Por Região')
ax.set_xticks(x)
ax.set_xticklabels(df["Regiao Residente"])
ax.legend()

plt.show()
plt.rcParams["figure.figsize"] = [15, 5]

# %%
df = df.dropna()

x = np.arange(len(df["Raça/cor"]))
width = 0.20
fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, (df["Masculino.2"]), width, label='Masculino')
rects2 = ax.bar(x + width/2, (df["Feminino.2"]), width, label='Masculino')

ax.set_ylabel('Casos')
ax.set_title('Casos Por Raça/cor')
ax.set_xticks(x)
ax.set_xticklabels(df["Raça/cor"])
ax.legend()

plt.show()
plt.rcParams["figure.figsize"] = [15, 5]
